# %%
import pandas as pd
import numpy as np
import os
os.getcwd()
os.listdir()

raw_data = pd.read_csv('adult.csv',na_values='?')
raw_data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18        NaN  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                NaN    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
####Data exploration 
raw_data.columns
##raw_data.info()

##raw_data.info()

obj_var = [ x for x in raw_data.columns if raw_data[x].dtype == 'object']
obj_var
##checking for distinct values 
for x in obj_var:
   print(x ,'\n', raw_data[x].value_counts())

raw_data
# Out:
# workclass
#  Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64
# education
#  HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64
# marital-status
#  Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: marital-status, dtype: int64
# occupation
# ...

# %%
##Target varaible changed to boolean
raw_data['income'].value_counts()

raw_data['income'] = raw_data['income'].apply(lambda x : x == '>50K')

#####splitting into X and Y
X = raw_data.drop('income',axis=1)
y = raw_data['income']

X.head(),y.head(10)
# Out:
# (   age  workclass  fnlwgt     education  educational-num      marital-status  \
#  0   25    Private  226802          11th                7       Never-married
#  1   38    Private   89814       HS-grad                9  Married-civ-spouse
#  2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
#  3   44    Private  160323  Some-college               10  Married-civ-spouse
#  4   18        NaN  103497  Some-college               10       Never-married
#
#            occupation relationship   race  gender  capital-gain  capital-loss  \
#  0  Machine-op-inspct    Own-child  Black    Male             0             0
#  1    Farming-fishing      Husband  White    Male             0             0
#  2    Protective-serv      Husband  White    Male             0             0
#  3  Machine-op-inspct      Husband  Black    Male          7688             0
#  4                NaN    Own-child  White  Female             0             0
#
# ...

# %%
###education and educational-num are ordinal type data.. so we can get rid of education as we already have educational-num
X.columns
X[['education','educational-num']].groupby('education',as_index=False).min().sort_values(by='educational-num')
# Out:
#        education  educational-num
# 13     Preschool                1
# 3        1st-4th                2
# 4        5th-6th                3
# 5        7th-8th                4
# 6            9th                5
# 0           10th                6
# 1           11th                7
# 2           12th                8
# 11       HS-grad                9
# 15  Some-college               10
# 8      Assoc-voc               11
# 7     Assoc-acdm               12
# 9      Bachelors               13
# 12       Masters               14
# 14   Prof-school               15
# 10     Doctorate               16

# %%
###Dropping unneccesary columns 
X = X.drop('education',axis=1)

# %%
##Also fnlwgt doesnt seem to be a relavant column so we willl drop that too 
X = X.drop('fnlwgt',axis=1)

# %%
##checkning the null values in the columns for imputation

X.isnull().sum().sort_values(ascending=False).head()
# Out:
# occupation        2809
# workclass         2799
# native-country     857
# hours-per-week       0
# capital-loss         0
# dtype: int64

# %%
###We see that united states is having the maximum number of observations, so we can bin others in others
X['native-country'].value_counts()
X['native-country'] = X['native-country'].map(lambda x: 'United-States' if x == 'United-States' else 'Others' )

# %%
###Lets check the unique number of values for other object features
##X.info()

obj_features = [x for x in X.columns if X[x].dtype == 'object']


##lets check the unique values 
for z in obj_features:
    length = len(X[z].unique())
    print(" {feature_name} : {length} ".format(feature_name=z,length=length))
 


### The number of unique values are not much so we can implement hot encoding for all of thee/ get_dummies 
##pd.get_dummies(X['workclass'],drop_first=True,prefix='workclass')

for x in obj_features :
    dummies = pd.get_dummies(X[x],drop_first=True,prefix=x,dummy_na=False)
    X=X.drop(x,axis=1)
    X = pd.concat([X,dummies],axis=1)
##X.info()
# Out:
#  workclass : 9
#  marital-status : 7
#  occupation : 15
#  relationship : 6
#  race : 5
#  gender : 2
#  native-country : 2

# %%
###Missing values---No missng values
##X.isnull().values.sum()

##from sklearn.preprocessing import Imputer
##imp = Imputer(missing_values='Nan',strategy='mean',axis=0)
##imp.fit(X)
##X = pd.DataFrame(data=imp.transform(X),columns=X.columns)

# %%
###Outliar detection
def outliar_detection(x):
    Q1_value = np.percentile(x,25)
    Q3_value = np.percentile(x,75)
    Q_range = 1.5 * (Q3_value - Q1_value)
    floor = Q1_value - Q_range
    ceiling = Q3_value + Q_range
    outliar_indices = list(x.index[(x<floor) | (x>ceiling)])
    outliar_values = list(x[outliar_indices])
    return (outliar_indices,outliar_values)

# %%
from sklearn.preprocessing import StandardScaler
####There are a lot of outliars and the graph is right skewed.. now we either take log transformation or scale it

##outliar = outliar_detection(X['hours-per-week'])
##outliar = outliar_detection(X['age'])
##print(outliar)
X['age'].value_counts()
X['hours-per-week'].value_counts()

##cols_to_scale = ['hours-per-week', 'age']
##standardSc = StandardScaler()
##standardSc.fit(X[cols_to_scale])
###X =  pd.Dataframe(data=standardSc.transform(X[cols_to_scale]),columns = X.columns)
# Out:
# 40    22803
# 50     4246
# 45     2717
# 60     2177
# 35     1937
# 20     1862
# 30     1700
# 55     1051
# 25      958
# 48      770
# 38      714
# 15      623
# 70      437
# 10      425
# 32      423
# 65      355
# 24      354
# 42      338
# 36      336
# 44      310
# 16      303
# 12      247
# 37      242
# 43      227
# 8       218
# 80      210
# 52      205
# 56      141
# 28      140
# 99      137
#       ...
# 19       19
# 57       19
# 85       17
# 68       16
# 63       15
# 29       15
# 98       14
# 78       13
# 31       12
# 96        9
# 77        9
# 59        7
# 67        6
# 76        4
# 61        4
# 73        4
# 86        4
# 88        4
# 74        3
# 92        3
# 81        3
# 91        3
# 89        3
# 97        2
# 95        2
# 69        1
# 94        1
# 79        1
# 82        1
# 87        1
# Name: hours-per-week, Length: 96, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
import warnings
warnings.filterwarnings('ignore')

from xgboost import XGBClassifier

from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier

###Cross validation 

seed=0
scoring = 'accuracy'
models = []

models.append(('LR', LogisticRegression()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('GB', GradientBoostingClassifier()))
models.append(('RF', RandomForestClassifier(n_jobs=-1)))


#SVM CRASHES SYS
#models.append(('SVM', SVC()))
# evaluate each model in turn
results = []
names = []
for name, model in models:
  kfold = model_selection.KFold(n_splits=10, random_state=seed)
  cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
  results.append(cv_results)
  names.append(name)
  msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
  print(msg)
# Out:
# LR: 0.850454 (0.005495)
# CART: 0.820753 (0.008318)
# NB: 0.825312 (0.004126)
# GB: 0.866015 (0.003762)
# RF: 0.846960 (0.004825)

# %%
gb = GradientBoostingClassifier()
gb.fit(X_train, y_train)
predictions = gb.predict(X_test)
print(accuracy_score(y_test, predictions))
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# 0.8707722545246089
# [[8834  439]
#  [1139 1799]]
#              precision    recall  f1-score   support
#
#       False       0.89      0.95      0.92      9273
#        True       0.80      0.61      0.70      2938
#
# avg / total       0.87      0.87      0.86     12211
